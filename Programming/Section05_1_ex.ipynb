# %% [markdown]
# <a href="https://colab.research.google.com/github/mako10/Lectures/blob/main/Programming/Section05_1_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Section 5-1 if文／条件で処理を分岐する　p.96

# %% [markdown]
# ##①条件に合えば実行する　if
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##②条件に合う場合の処理と合わない場合の処理　if ～ else
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##③3つ以上の選択肢がある場合　if ～ elif ～ else
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##④if文のネスティングと論理演算
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##⑤条件式を簡略化して書く
# ![image.png](data:image/png;base64,...)
# if ～ else 文を一行で書くこと。

# %% [markdown]
# 以上
