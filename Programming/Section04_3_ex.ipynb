# %% [markdown]
# <a href="https://colab.research.google.com/github/mako10/Lectures/blob/main/Programming/Section04_3_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Section 4-3 オブジェクトのメソッド　p.83

# %% [markdown]
# ##①オブジェクトのメソッドを実行する
# 1．変数 s に "Hello world!" を代入する
# 2．変数 s の型を調べる
# 3．変数 s の先頭を大文字にする

# %% [markdown]
# 以上
