# %% [markdown]
# #Section 4-4 文字列のメソッド　p.83

# %% [markdown]
# ##①　大文字小文字の変換
#
#
# 1.   s に "Apple" を代入する
# 2.   s を全て小文字にする
# 3.   s を全て大文字にする

# %% [markdown]
# ##②　文字列を検索する
# "Apple juice" から "j" の位置を求める

# %% [markdown]
# 以上
